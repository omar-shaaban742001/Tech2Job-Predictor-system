# %% [markdown]
# # Explore Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_row" , None)
pd.set_option("display.max_column" , None)

# %%
DATA_PATH = "/content/drive/MyDrive/Colab Notebooks/datasets/survey_results_public.csv"

# %%
# Read datset into a data frame
raw_df = pd.read_csv(DATA_PATH)

# %%
# Show a random sample
raw_df.sample(1).iloc[0]
# Out:
# ResponseId                                                                    52363
# MainBranch                                           I am a developer by profession
# Age                                                                 35-44 years old
# Employment                                                      Employed, full-time
# RemoteWork                                     Hybrid (some remote, some in-person)
# Check                                                                        Apples
# CodingActivities                  Hobby;Professional development or self-paced l...
# EdLevel                                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                         Books / Physical media;On the job training;Onl...
# LearnCodeOnline                                                                 NaN
# TechDoc                                                                         NaN
# ...

# %%
raw_df.head(5)
# Out:
#    ResponseId                      MainBranch  ... ConvertedCompYearly JobSat
# 0           1  I am a developer by profession  ...                 NaN    NaN
# 1           2  I am a developer by profession  ...                 NaN    NaN
# 2           3  I am a developer by profession  ...                 NaN    NaN
# 3           4           I am learning to code  ...                 NaN    NaN
# 4           5  I am a developer by profession  ...                 NaN    NaN
#
# [5 rows x 114 columns]

# %%
raw_df.shape
# Out:
# (65437, 114)

# %%
raw_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Data columns (total 114 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    ResponseId                      int64
#  1    MainBranch                      object
#  2    Age                             object
#  3    Employment                      object
#  4    RemoteWork                      object
#  5    Check                           object
#  6    CodingActivities                object
#  7    EdLevel                         object
#  8    LearnCode                       object
#  9    LearnCodeOnline                 object
#  10   TechDoc                         object
#  11   YearsCode                       object
#  12   YearsCodePro                    object
#  13   DevType                         object
#  14   OrgSize                         object
#  15   PurchaseInfluence               object
# ...

# %%
# Explore some weird data type columns
questionable_cols = ['YearsCodePro', 'YearsCode']

for col in questionable_cols:
  print(col)
  print(raw_df[col].unique().tolist())
  print("----------------------------------\n")
# Out:
# YearsCodePro
# [nan, '17', '27', '7', '11', '25', '12', '10', '3', 'Less than 1 year', '18', '37', '15', '20', '6', '2', '16', '8', '14', '4', '45', '1', '24', '29', '5', '30', '26', '9', '33', '13', '35', '23', '22', '31', '19', '21', '28', '34', '32', '40', '50', '39', '44', '42', '41', '36', '38', 'More than 50 years', '43', '47', '48', '46', '49']
# ----------------------------------
#
# YearsCode
# [nan, '20', '37', '4', '9', '10', '7', '1', '15', '30', '31', '6', '12', '22', '5', '36', '25', '44', '24', '18', '3', '8', 'More than 50 years', '11', '29', '40', '39', '2', '42', '34', '19', '35', '16', '33', '13', '23', '14', '28', '17', '21', '43', '46', '26', '32', '41', '45', '27', '38', '50', '48', '47', 'Less than 1 year', '49']
# ----------------------------------

# %% [markdown]
# # Insights
# *   many columns need to be splitted
# *   yearscode and yearscodepro need to be convertred from object to float
